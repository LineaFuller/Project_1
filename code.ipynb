# %%
import requests
import json
from pprint import pprint
import pandas as pd
import time

# %%
# USA Yearly change for Temperature
url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/tas/year/USA"
request = requests.get(url).json()
# pprint(request)
len(request)
year = []
data = []
for x in range(len(request)):
    year.append(request[x]['year'])
    data.append(request[x]['data'])
year_df = pd.DataFrame({"Year": year,
                       "Temperature": data})

year_df.head()
# Out:
#    Year  Temperature
# 0  1901     6.618749
# 1  1902     6.464327
# 2  1903     6.073844
# 3  1904     6.149883
# 4  1905     6.599617

# %%
# AUS Yearly change for Temperature
url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/tas/year/AUS"
request = requests.get(url).json()
# pprint(request)
len(request)
year = []
data = []
for x in range(len(request)):
    year.append(request[x]['year'])
    data.append(request[x]['data'])
year_df = pd.DataFrame({"Year": year,
                       "Temperature": data})

year_df.head()
# Out:
#    Year  Temperature
# 0  1901    21.357021
# 1  1902    21.382462
# 2  1903    20.936884
# 3  1904    20.791357
# 4  1905    20.954510

# %%
# USA mavg Precipitation(1980-1999) data
rain_url = url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/USA"

# Request
rain_response = requests.get(rain_url).json()

# Print
pprint(rain_response)
# Out:
# [{'fromYear': 1980,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [54.08542875,
#                 50.10966809,
#                 59.51437374,
#                 65.55661286,
#                 70.43493967,
#                 68.00114649,
#                 74.48428044,
#                 74.43675767,
#                 76.55364909,
#                 69.6023086,
#                 65.11055405,
#                 57.89741514],
#   'toYear': 1999,
#   'variable': 'pr'},
#  {'fromYear': 1980,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [62.24072027,
#                 57.24048448,
#                 60.46462325,
#                 59.70685447,
#                 65.48141856,
#                 67.01421827,
#                 68.07160133,
#                 65.0143177,
#                 66.89814055,
#                 64.13912761,
#                 71.3859928,
#                 70.08152903],
#   'toYear': 1999,
#   'variable': 'pr'},
#  {'fromYear': 1980,
#   'gcm': 'cnrm_cm3',
# ...

# %%
# Monthly avg precipitation dataframe 
df["Precipiation(1980-1999)"] = rain_response[0]['monthVals']

# Display
df
# Out:
#         Month  Average Temp (1980 - 1999)  Precipiation(1980-1999)
# 0     January                   -9.621845                54.085429
# 1    February                   -8.451683                50.109668
# 2       March                   -3.776518                59.514374
# 3       April                    2.673571                65.556613
# 4         May                    9.254254                70.434940
# 5        June                   14.923076                68.001146
# 6        July                   18.226249                74.484280
# 7      August                   17.891722                74.436758
# 8   September                   13.545309                76.553649
# 9     October                    6.414062                69.602309
# 10   November                   -0.960048                65.110554
# 11   December                   -6.717319                57.897415

# %%
# USA mavg Temp(1940-1959) data

older_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1940/1959/USA"

older_response = requests.get(older_url).json()

pprint(older_response)
# Out:
# [{'fromYear': 1940,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [-10.15891557,
#                 -8.92103649,
#                 -4.480659199,
#                 2.211140583,
#                 8.659985169,
#                 14.12858357,
#                 18.06787353,
#                 17.69644591,
#                 13.25482535,
#                 6.582813748,
#                 -1.204904228,
#                 -7.46817439],
#   'toYear': 1959,
#   'variable': 'tas'},
#  {'fromYear': 1940,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [-7.948959084,
#                 -6.97074072,
#                 -2.95616968,
#                 3.182227917,
#                 9.766846616,
#                 14.84157496,
#                 17.71952831,
#                 17.1666727,
#                 12.68447351,
#                 6.437941135,
#                 -0.065550198,
#                 -5.438898786],
#   'toYear': 1959,
#   'variable': 'tas'},
#  {'fromYear': 1940,
#   'gcm': 'cnrm_cm3',
# ...

# %%
df["Average Temp(1940-1959)"] = older_response[0]['monthVals']

df
# Out:
#         Month  Average Temp (1980 - 1999)  Precipiation(1980-1999)  \
# 0     January                   -9.621845                54.085429
# 1    February                   -8.451683                50.109668
# 2       March                   -3.776518                59.514374
# 3       April                    2.673571                65.556613
# 4         May                    9.254254                70.434940
# 5        June                   14.923076                68.001146
# 6        July                   18.226249                74.484280
# 7      August                   17.891722                74.436758
# 8   September                   13.545309                76.553649
# 9     October                    6.414062                69.602309
# 10   November                   -0.960048                65.110554
# 11   December                   -6.717319                57.897415
#
#     Average Temp(1940-1959)
# 0                -10.158916
# 1                 -8.921036
# ...

# %%
# USA mavg Precipitation(1940-1959) data

older_pr_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1940/1959/USA"

pr_response = requests.get(older_pr_url).json()

pprint(pr_response)
# Out:
# [{'fromYear': 1940,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [56.02172327,
#                 50.80353646,
#                 60.84075182,
#                 63.11362501,
#                 71.05330457,
#                 68.20698072,
#                 73.07779172,
#                 77.57282465,
#                 75.87185244,
#                 67.09686444,
#                 60.2682821,
#                 56.69994225],
#   'toYear': 1959,
#   'variable': 'pr'},
#  {'fromYear': 1940,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [59.70687965,
#                 50.22217794,
#                 56.80745812,
#                 56.97393531,
#                 64.95357607,
#                 65.40850762,
#                 66.22503086,
#                 62.59095353,
#                 63.82555805,
#                 62.91143598,
#                 68.47809455,
#                 68.63599124],
#   'toYear': 1959,
#   'variable': 'pr'},
#  {'fromYear': 1940,
#   'gcm': 'cnrm_cm3',
# ...

# %%
df["Precipitation(1940-1959)"]= pr_response[0]['monthVals']

df

df.to_csv("USA_df.csv")
# Out:
#         Month  Average Temp (1980 - 1999)  Precipiation(1980-1999)  \
# 0     January                   -9.621845                54.085429
# 1    February                   -8.451683                50.109668
# 2       March                   -3.776518                59.514374
# 3       April                    2.673571                65.556613
# 4         May                    9.254254                70.434940
# 5        June                   14.923076                68.001146
# 6        July                   18.226249                74.484280
# 7      August                   17.891722                74.436758
# 8   September                   13.545309                76.553649
# 9     October                    6.414062                69.602309
# 10   November                   -0.960048                65.110554
# 11   December                   -6.717319                57.897415
#
#     Average Temp(1940-1959)  Precipitation(1940-1959)
# ...

# %%
# AUS mavg Temp(1980-1999) data
aus_1990_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/AUS"

aus_1990_response = requests.get(aus_1990_url).json()

pprint(aus_1990_response)
# Out:
# [{'fromYear': 1980,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [25.87815308,
#                 25.43440959,
#                 24.16736274,
#                 21.87514947,
#                 18.2866508,
#                 14.87427667,
#                 13.97126723,
#                 15.74230903,
#                 18.38154405,
#                 21.80694187,
#                 23.8718099,
#                 25.00430203],
#   'toYear': 1999,
#   'variable': 'tas'},
#  {'fromYear': 1980,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [27.45818427,
#                 26.95512912,
#                 24.79270766,
#                 21.41736179,
#                 16.97484212,
#                 13.99668443,
#                 12.90537313,
#                 14.47393853,
#                 17.90757433,
#                 22.16288276,
#                 25.20553833,
#                 27.28776096],
#   'toYear': 1999,
#   'variable': 'tas'},
#  {'fromYear': 1980,
#   'gcm': 'cnrm_cm3',
# ...

# %%
# Put data into list
aus_response = aus_1990_response[0]['monthVals']

#Create list of months
month = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Put into a DataFrame
df = pd.DataFrame({"AUS Month": month,
                    "Average Temp (1980 - 1999)": aus_response})

df
# Out:
#     AUS Month  Average Temp (1980 - 1999)
# 0     January                   25.878153
# 1    February                   25.434410
# 2       March                   24.167363
# 3       April                   21.875149
# 4         May                   18.286651
# 5        June                   14.874277
# 6        July                   13.971267
# 7      August                   15.742309
# 8   September                   18.381544
# 9     October                   21.806942
# 10   November                   23.871810
# 11   December                   25.004302

# %%
# AUS mavg Precipitation(1980-1999) data
aus_1990_pr_url = aus_1990_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/AUS"

aus_1990_pr_response = requests.get(aus_1990_pr_url).json()

pprint(aus_1990_pr_response)
# Out:
# [{'fromYear': 1980,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [145.2147442,
#                 152.1000659,
#                 132.2469297,
#                 95.78192808,
#                 65.68873722,
#                 46.7608082,
#                 47.37453042,
#                 42.63793169,
#                 49.62307584,
#                 58.67578397,
#                 86.57668973,
#                 136.4244906],
#   'toYear': 1999,
#   'variable': 'pr'},
#  {'fromYear': 1980,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [62.75995045,
#                 66.69719343,
#                 66.16181581,
#                 39.0572022,
#                 37.75383592,
#                 34.66583859,
#                 29.49465083,
#                 29.05384564,
#                 25.57699883,
#                 21.25628535,
#                 23.16091196,
#                 30.46213946],
#   'toYear': 1999,
#   'variable': 'pr'},
#  {'fromYear': 1980,
#   'gcm': 'cnrm_cm3',
# ...

# %%
df["Monthly Precipitation (1980-1999)"] = aus_1990_pr_response[0]['monthVals']

df
# Out:
#     AUS Month  Average Temp (1980 - 1999)  Monthly Precipitation (1980-1999)
# 0     January                   25.878153                         145.214744
# 1    February                   25.434410                         152.100066
# 2       March                   24.167363                         132.246930
# 3       April                   21.875149                          95.781928
# 4         May                   18.286651                          65.688737
# 5        June                   14.874277                          46.760808
# 6        July                   13.971267                          47.374530
# 7      August                   15.742309                          42.637932
# 8   September                   18.381544                          49.623076
# 9     October                   21.806942                          58.675784
# 10   November                   23.871810                          86.576690
# ...

# %%
# AUS mavg Precipitation(1980-1999) data
aus_rain_url = url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/AUS"

# Request
aus_rain_response = requests.get(rain_url).json()

# Print
pprint(rain_response)
# Out:
# [{'fromYear': 1980,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [54.08542875,
#                 50.10966809,
#                 59.51437374,
#                 65.55661286,
#                 70.43493967,
#                 68.00114649,
#                 74.48428044,
#                 74.43675767,
#                 76.55364909,
#                 69.6023086,
#                 65.11055405,
#                 57.89741514],
#   'toYear': 1999,
#   'variable': 'pr'},
#  {'fromYear': 1980,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [62.24072027,
#                 57.24048448,
#                 60.46462325,
#                 59.70685447,
#                 65.48141856,
#                 67.01421827,
#                 68.07160133,
#                 65.0143177,
#                 66.89814055,
#                 64.13912761,
#                 71.3859928,
#                 70.08152903],
#   'toYear': 1999,
#   'variable': 'pr'},
#  {'fromYear': 1980,
#   'gcm': 'cnrm_cm3',
# ...

# %%
# AUS mavg precipitation dataframe 
df["Precipiation(1980-1999)"] = aus_rain_response[0]['monthVals']

# Display
df
# Out:
#     AUS Month  Average Temp (1980 - 1999)  Monthly Precipitation (1980-1999)  \
# 0     January                   25.878153                         145.214744
# 1    February                   25.434410                         152.100066
# 2       March                   24.167363                         132.246930
# 3       April                   21.875149                          95.781928
# 4         May                   18.286651                          65.688737
# 5        June                   14.874277                          46.760808
# 6        July                   13.971267                          47.374530
# 7      August                   15.742309                          42.637932
# 8   September                   18.381544                          49.623076
# 9     October                   21.806942                          58.675784
# 10   November                   23.871810                          86.576690
# ...

# %%
# AUS mavg Temp(1940-1959) data

aus_older_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1940/1959/AUS"

aus_older_response = requests.get(older_url).json()

pprint(aus_older_response)
# Out:
# [{'fromYear': 1940,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [-10.15891557,
#                 -8.92103649,
#                 -4.480659199,
#                 2.211140583,
#                 8.659985169,
#                 14.12858357,
#                 18.06787353,
#                 17.69644591,
#                 13.25482535,
#                 6.582813748,
#                 -1.204904228,
#                 -7.46817439],
#   'toYear': 1959,
#   'variable': 'tas'},
#  {'fromYear': 1940,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [-7.948959084,
#                 -6.97074072,
#                 -2.95616968,
#                 3.182227917,
#                 9.766846616,
#                 14.84157496,
#                 17.71952831,
#                 17.1666727,
#                 12.68447351,
#                 6.437941135,
#                 -0.065550198,
#                 -5.438898786],
#   'toYear': 1959,
#   'variable': 'tas'},
#  {'fromYear': 1940,
#   'gcm': 'cnrm_cm3',
# ...

# %%
# AUS mavg Temp 1940-1959 
df["Average Temp(1940-1959)"] = aus_older_response[0]['monthVals']

df
# Out:
#     AUS Month  Average Temp (1980 - 1999)  Monthly Precipitation (1980-1999)  \
# 0     January                   25.878153                         145.214744
# 1    February                   25.434410                         152.100066
# 2       March                   24.167363                         132.246930
# 3       April                   21.875149                          95.781928
# 4         May                   18.286651                          65.688737
# 5        June                   14.874277                          46.760808
# 6        July                   13.971267                          47.374530
# 7      August                   15.742309                          42.637932
# 8   September                   18.381544                          49.623076
# 9     October                   21.806942                          58.675784
# 10   November                   23.871810                          86.576690
# ...

# %%
# AUS mavg Precipitation(1940-1959) data

aus_older_pr_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1940/1959/AUS"

aus_pr_response = requests.get(older_pr_url).json()

pprint(aus_pr_response)
# Out:
# [{'fromYear': 1940,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [56.02172327,
#                 50.80353646,
#                 60.84075182,
#                 63.11362501,
#                 71.05330457,
#                 68.20698072,
#                 73.07779172,
#                 77.57282465,
#                 75.87185244,
#                 67.09686444,
#                 60.2682821,
#                 56.69994225],
#   'toYear': 1959,
#   'variable': 'pr'},
#  {'fromYear': 1940,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [59.70687965,
#                 50.22217794,
#                 56.80745812,
#                 56.97393531,
#                 64.95357607,
#                 65.40850762,
#                 66.22503086,
#                 62.59095353,
#                 63.82555805,
#                 62.91143598,
#                 68.47809455,
#                 68.63599124],
#   'toYear': 1959,
#   'variable': 'pr'},
#  {'fromYear': 1940,
#   'gcm': 'cnrm_cm3',
# ...

# %%
# AUS mavg Precipitation(1940-1959) df
df["Precipitation(1940-1959)"]= aus_pr_response[0]['monthVals']

df

df.to_csv("AUS_df.csv")
# Out:
#     AUS Month  Average Temp (1980 - 1999)  Monthly Precipitation (1980-1999)  \
# 0     January                   25.878153                         145.214744
# 1    February                   25.434410                         152.100066
# 2       March                   24.167363                         132.246930
# 3       April                   21.875149                          95.781928
# 4         May                   18.286651                          65.688737
# 5        June                   14.874277                          46.760808
# 6        July                   13.971267                          47.374530
# 7      August                   15.742309                          42.637932
# 8   September                   18.381544                          49.623076
# 9     October                   21.806942                          58.675784
# 10   November                   23.871810                          86.576690
# ...

# %%
daily_min_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/USA"

response = requests.get(past_url).json()


pprint(response)
# Out:
# [{'fromYear': 1920,
#   'gcm': 'bccr_bcm2_0',
#   'monthVals': [-10.61768879,
#                 -8.407692545,
#                 -4.116470908,
#                 2.330464732,
#                 8.79204721,
#                 14.26015573,
#                 17.92173231,
#                 17.58278399,
#                 13.33264472,
#                 6.479564486,
#                 -1.224032243,
#                 -7.690621583],
#   'toYear': 1939,
#   'variable': 'tas'},
#  {'fromYear': 1920,
#   'gcm': 'cccma_cgcm3_1',
#   'monthVals': [-7.637799536,
#                 -7.092528003,
#                 -2.944350169,
#                 3.280084929,
#                 9.396691149,
#                 14.40580571,
#                 17.40768326,
#                 17.18583843,
#                 12.63803991,
#                 6.334863753,
#                 -0.079385201,
#                 -5.376437446],
#   'toYear': 1939,
#   'variable': 'tas'},
#  {'fromYear': 1920,
#   'gcm': 'cnrm_cm3',
# ...

# %%
future_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/var/1901/2012/USA"

response = requests.get(future_url).json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-53-251e188bedf1> in <module>
#       1 future_url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/var/1920/1939/USA"
#       2
# ----> 3 response = requests.get(future_url).json()
#       4
#       5
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# ...
